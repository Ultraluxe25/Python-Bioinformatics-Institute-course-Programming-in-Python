# %% [markdown]
# ### Пространство имен - это множество всех ссылок на созданные объекты

# %% [markdown]
# ![image.png](attachment:c3290323-7244-4436-98f1-3689be331f2d.png)
# ### Built-in - это пространство имен интерпретатора, оно содержит все имена функций стандартной библиотеки Python

# %% [markdown]
# ![image.png](attachment:82bb7b2f-0779-4280-bed4-e68f6d280ac3.png)

# %% [markdown]
# # Задача 6
# ![image.png](attachment:3aa3fe3e-bd94-4e8d-94f2-581370da19f0.png)

# %% [markdown]
# ![image.png](attachment:43156558-27de-4b17-b277-7e691b6f668e.png)

# %% [markdown]
# ![image.png](attachment:20ab4d63-d202-4e31-b5b2-760962491744.png)

# %% [markdown]
# ![image.png](attachment:ed050a65-8837-422b-8bca-0b64a270f107.png)

# %% [markdown]
# # https://pythontutor.com/render.html#mode=display

# %% [markdown]
# ![image.png](attachment:d0237caa-dde7-459b-8600-b27952a69fe9.png)

# %% [markdown]
# ![image.png](attachment:2f18a93e-a6d0-48b8-81ec-18ce0aed7a1e.png)

# %% [markdown]
# ![image.png](attachment:1962b766-fb6a-4114-9978-62d90bfba5bd.png)

# %% [markdown]
# ![image.png](attachment:cc213e8a-9b92-4c4c-8ddb-7b15f5d4ddb5.png)
# ### Области видимости

# %% [markdown]
# ![image.png](attachment:83e07f0b-e062-488c-bcf3-f344152d61bc.png)
# ### Поиск функции или значения переменной будет осуществляться от local до built-in

# %% [markdown]
# ![image.png](attachment:1e693334-b3a7-4249-850e-51f985b11d90.png)
# ### Здесь интерпретатор не заскочет в область видимости функции b, а пойдет искать выше в глубину
