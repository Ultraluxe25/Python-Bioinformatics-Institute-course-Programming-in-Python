# %% [markdown]
# ![image.png](attachment:03ebffd5-f31b-4e84-9723-3f4403a0eb40.png)

# %% [markdown]
# ### У компиляторов есть промежуточный код в виде байт кода или ассемблерного, интерпретатор же выполняет код построчно

# %% [markdown]
# ![image.png](attachment:7f88e842-76eb-4e39-a120-580bc9dcde7e.png)

# %% [markdown]
# ![image.png](attachment:da05e8a8-a8d8-468c-a86f-cc4fb3ef6c42.png)

# %% [markdown]
# ![image.png](attachment:906f3005-9513-4190-a111-709c89b28f6c.png)

# %% [markdown]
# ![image.png](attachment:e833bff2-b497-432c-a492-f0fab12ce9c9.png)

# %% [markdown]
# ### Неизменяемые числа создают новый объект, а не изменяют старый

# %% [markdown]
# # <span style="color: red">Значения списка - это упорядоченное множество ссылок на объекты

# %% [markdown]
# # PEP-8
# ![image.png](attachment:9aa75555-c2c4-4ef5-834f-6faa6350e37a.png)

# %% [markdown]
# ### При работе с неизменяемыми типами не всегда нужно создавать объект в памяти компьютера. Просто можно использовать уже существующий и увеличит количество ссылок на него на одну. Когда создается новый неизменяемый тип данных, то он всегда создает новый объект, даже если новый список содержит те же элементы что и старый

# %% [markdown]
# # Задача 1
# ![image.png](attachment:63c4a3af-6c50-4790-a7ad-451af294e037.png)
# ![image.png](attachment:f79b662f-0b47-4690-a047-b24c9fa1455b.png)

# %% [markdown]
# ### Есть всего 3 причины использования функции в коде:
# - переиспользование
# - структурирование (лучшая читабельность)
# - абстрагирования от сокрытой части

# %% [markdown]
# ### Интерпретотор не исполняет определение функции построчно, а исполняет её целиком

# %% [markdown]
# # Задача 2
# ![image.png](attachment:8871219c-9714-463f-83ab-984230cd9f8d.png)
# ### Stack(module, g, f, g, h, print)

# %% [markdown]
# ### Единственный способ проверить ссылается ли переменная на None, это проверить используя **is**

# %% [markdown]
# # Задача 3
# ![image.png](attachment:0c953cfc-e0eb-484e-b652-bfcc95a5a57b.png)

# %% [markdown]
# ![image.png](attachment:269e2283-eca6-43d4-91a1-0ded2a8b789c.png)

# %% [markdown]
# ### Сначала указываем позиционные аргументы, а потом именованные

# %% [markdown]
# ![image.png](attachment:a128e6b4-74cf-4094-9d18-b367ee182054.png)

# %% [markdown]
# # Задача 4
# ![image.png](attachment:670069e2-2031-4a8d-b7c4-597a8c5b636f.png)
# ![image.png](attachment:62d33f7b-0d66-46cd-b573-2d4a4d879525.png)
# ![image.png](attachment:c532140c-a8bb-485c-b712-757bd666ed71.png)
# ![image.png](attachment:abab5a25-e420-4649-b914-58135c30d9dd.png)

# %% [markdown]
# ![image.png](attachment:e3eae019-bc5b-44f2-bc46-a0972a1bf493.png)

# %% [markdown]
# ![image.png](attachment:fd197855-f3df-453f-9544-83818c7149af.png)

# %% [markdown]
# ![image.png](attachment:51f733cc-d0b7-4b24-a9ab-4f0b716abc1b.png)

# %% [markdown]
# # Задача 5
# ![image.png](attachment:53ec800a-4f82-46c0-9f1f-6e63c32aa166.png)

# %% [markdown]
# ![image.png](attachment:66b125ae-f300-4e1b-9edd-57c9561edb3a.png)

# %%
def s(a, *vs, b=10):
   res = a + b
   for v in vs:
       res += v
   return res

# %%
s(11, 10, b=10)
# Out:
# 31

# %%
s(5, 5, 5, 5, 1)
# Out:
# 31

# %%
s(11, 10)
# Out:
# 31

# %%
s(11, b=20)
# Out:
# 31

# %%
s(21)
# Out:
# 31
