# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В качестве ответа от сервера часто получается html-документ со структурой веб страницы.

# %%
import requests

res = requests.get(url='https://docs.python.org/3.14/')
res
# Out:
# <Response [200]>

# %%
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '3693', 'server': 'nginx', 'content-type': 'text/html', 'last-modified': 'Mon, 02 Feb 2026 10:36:11 GMT', 'etag': '"69807e1b-458a"', 'x-clacks-overhead': 'GNU Terry Pratchett', 'strict-transport-security': 'max-age=315360000; includeSubDomains; preload', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Age': '3384', 'Date': 'Mon, 02 Feb 2026 12:37:58 GMT', 'X-Served-By': 'cache-lga21979-LGA, cache-mxp6933-MXP', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '28, 0', 'X-Timer': 'S1770035879.565443,VS0,VE240', 'Vary': 'Accept-Encoding'}

# %%
# res.content

# %%
# print(res.text)

# %%
res.url
# Out:
# 'https://docs.python.org/3.14/'

# %% [markdown]
# ### Записываем ответ сервера в html файл.

# %%
with open('python 3.14 - main.html', 'wb') as f:
    f.write(res.content)
